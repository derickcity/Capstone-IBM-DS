# %% [markdown]
# ## The Battle of the Neighborhoods - Week 2

# %% [markdown]
# ## Table of contents
# * [Introduction](#introduction)
# * [Business Problem](#BusinessProblem)
# * [Data](#data)

# %% [markdown]
# ### Introduction <a name="introduction"></a>

# %% [markdown]
# The city of Calgary is one of the largest municipalities Canada located in the province of Alberta. The city had a population of 1,285,711 in 2019, making it Alberta's largest city and Canada's third-largest municipality.
#
# Calgary's economy includes activity in the energy, financial services, film and television, transportation and logistics, technology, manufacturing, aerospace, health and wellness, retail, and tourism sectors.
#
# The Calgary Metropolitan Area (CMA) is home to Canada's second-highest number of corporate head offices among the country's 800 largest corporations.
#
# With a thriving population and rich economy like this, there is no doubt a restaurant might be a good business venture in the city of Calgary.
#
# However, an investor needs to be confident that they are making the right considerations before setting up a restaurant business in the city Calgary.

# %% [markdown]
# ### Business Problem <a name="BusinessProblem"></a>

# %% [markdown]
# With the purpose in mind, finding the right location to open a thriving restaurant is one of the crucial factors to guarantee success in this business venture.
#
# In this Capstone project, I will be focussing on different types of restaurants which are opened or closed in a particular location and then decide if it is good place to open a new restaurant based on the popular cuisine around that place. By using location analytics and machine learning algorithms such as clustering, this project aims to provide solutions to answer these business questions.

# %% [markdown]
# ### Source of Data <a name="data"></a>

# %% [markdown]
# For this analysis, I will be using the "List of neighbourhoods in Calgary" data scraped from Wikipedia
#  (https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Calgary).
#
# From the scraped data, there are total 257 neighbourhoods are in Calgary. The data will be trimmed down to two features ("Name" and "Sector") to remove irrelevant data for this analysis.

# %%
# !pip install lxml
# !pip3 install html5lib
# Out:
# Requirement already satisfied: lxml in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (3.6.4)
# WARNING: You are using pip version 19.2.2, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting html5lib
#   Downloading https://files.pythonhosted.org/packages/a5/62/bbd2be0e7943ec8504b517e62bab011b4946e1258842bc159e5dfde15b96/html5lib-1.0.1-py2.py3-none-any.whl (117kB)
#      |████████████████████████████████| 122kB 3.5MB/s eta 0:00:01
# Collecting webencodings (from html5lib)
#   Using cached https://files.pythonhosted.org/packages/f4/24/2a3e3df732393fed8b3ebf2ec078f05546de641fe1b667ee316ec1dcf3b7/webencodings-0.5.1-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.9 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from html5lib) (1.11.0)
# Installing collected packages: webencodings, html5lib
# Successfully installed html5lib-1.0.1 webencodings-0.5.1
# WARNING: You are using pip version 19.2.2, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
#import libraries
import pandas as pd
import requests
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors
import lxml.html as lh
import html5lib
import urllib.request

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Calgary', header =0, flavor = 'bs4')
print('Data inserted into dataframe')
# Out:
# Data inserted into dataframe

# %%
calgary_df = df[0]
#Exploring the dataset
calgary_df.head()
# Out:
#                         Name[9] Quadrant Sector[10] Ward[11]     Type[10]  \
# 0                     Abbeydale    NE/SE  Northeast       10  Residential
# 1                        Acadia       SE      South        9  Residential
# 2  Albert Park/Radisson Heights       SE       East       10  Residential
# 3                      Altadore       SW     Centre       11  Residential
# 4              Alyth/Bonnybrook       SE     Centre        9   Industrial
#
#    2012 PopulationRank  Population(2012)[9]  Population(2011)[9] % change  \
# 0                 82.0               5917.0               5700.0      3.8
# 1                 27.0              10705.0              10615.0      0.8
# 2                 75.0               6234.0               6217.0      0.3
# 3                 39.0               9116.0               8907.0      2.3
# 4                208.0                 16.0                 17.0     −5.9
#
#    Dwellings(2012)[9] Area(km2)[10] Populationdensity
# 0              2023.0           1.7            3480.6
# 1              5053.0           3.9            2744.9
# 2              2709.0           2.5            2493.6
# 3              4486.0           2.9            3143.4
# 4                14.0           3.8               4.2

# %% [markdown]
# The data will be enriched by writing a function to append "Calgary" to each neighborhood to enhance the chances of looking up the coordinates of each neighborhood.
# Further enrichment of the data to include the coordinates (latitude and longitude) of each neighbourhood using the geopy library.

# %%
calgary_df.drop(["Quadrant","Ward[11]", "Type[10]","2012 PopulationRank","Population(2012)[9]","Population(2011)[9]","% change","Dwellings(2012)[9]","Area(km2)[10]","Populationdensity"], axis=1,inplace=True)
calgary_df.columns = ['Neighborhood', 'Location']

# %%
calgary_df['Location'] = calgary_df['Location'].apply(lambda x: "{}{}".format(x, ', Calgary'))
calgary_df.head()
# Out:
#                    Neighborhood            Location
# 0                     Abbeydale  Northeast, Calgary
# 1                        Acadia      South, Calgary
# 2  Albert Park/Radisson Heights       East, Calgary
# 3                      Altadore     Centre, Calgary
# 4              Alyth/Bonnybrook     Centre, Calgary

# %%
calgary_df.shape
# Out:
# (258, 2)

# %%
# !pip install geoPy
# Out:
# Collecting geoPy
#   Downloading https://files.pythonhosted.org/packages/80/93/d384479da0ead712bdaf697a8399c13a9a89bd856ada5a27d462fb45e47b/geopy-1.20.0-py2.py3-none-any.whl (100kB)
#      |████████████████████████████████| 102kB 832kB/s ta 0:00:011
# Collecting geographiclib<2,>=1.49 (from geoPy)
#   Downloading https://files.pythonhosted.org/packages/5b/ac/4f348828091490d77899bc74e92238e2b55c59392f21948f296e94e50e2b/geographiclib-1.49.tar.gz
# Building wheels for collected packages: geographiclib
#   Building wheel for geographiclib (setup.py) ... done
#   Created wheel for geographiclib: filename=geographiclib-1.49-cp35-none-any.whl size=36987 sha256=f2f153b4630e298a510357a634e1306541fe93cb3de83b9ca472c3deac2e6512
#   Stored in directory: /home/nbuser/.cache/pip/wheels/99/45/d1/14954797e2a976083182c2e7da9b4e924509e59b6e5c661061
# Successfully built geographiclib
# Installing collected packages: geographiclib, geoPy
# Successfully installed geoPy-1.20.0 geographiclib-1.49
# WARNING: You are using pip version 19.2.2, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ## Convert addresses into Latitude and Longitude

# %%
from geopy.geocoders import Nominatim
lat=[]
lng=[]
def getLatLng(row):
    geolocator = Nominatim(user_agent='foursquare')
    print(row[0]+', '+row[1])
    location = geolocator.geocode(row[0]+', '+row[1])
    if location != None:
        lat.append(location.latitude)
        lng.append(location.longitude)
    else:
        lat.append(None)
        lng.append(None)

# %%
calgary_df.apply(getLatLng, axis=1)
# Out:
# Abbeydale, Northeast, Calgary
# Acadia, South, Calgary
# Albert Park/Radisson Heights, East, Calgary
# Altadore, Centre, Calgary
# Alyth/Bonnybrook, Centre, Calgary
# Applewood Park, East, Calgary
# Arbour Lake, Northwest, Calgary
# Aspen Woods, West, Calgary
# Auburn Bay, Southeast, Calgary
# Aurora Business Park, North, Calgary
# Banff Trail, Centre, Calgary
# Bankview, Centre, Calgary
# Bayview, South, Calgary
# Beddington Heights, North, Calgary
# Bel-Aire, Centre, Calgary
# Beltline, Centre, Calgary
# Bonavista Downs, South, Calgary
# Bowness, Northwest, Calgary
# Braeside, South, Calgary
# Brentwood, Northwest, Calgary
# Bridgeland/Riverside, Centre, Calgary
# Bridlewood, South, Calgary
# Britannia, Centre, Calgary
# Burns Industrial, Centre, Calgary
# Calgary International Airport, Northeast, Calgary
# Cambrian Heights, Centre, Calgary
# Canada Olympic Park, West, Calgary
# Canyon Meadows, South, Calgary
# Capitol Hill, Centre, Calgary
# South Calgary, Centre, Calgary
# South Foothills, Southeast, Calgary
# Southview, East, Calgary
# Southwood, South, Calgary
# Springbank Hill, West, Calgary
# Spruce Cliff, West, Calgary
# St. Andrews Heights, Centre, Calgary
# Starfield, East, Calgary
# Stonegate Landing, Northeast, Calgary
# Stoney 1, North, Calgary
# Stoney 2, Northeast, Calgary
# Stoney 3, Northeast, Calgary
# Stoney 4, Northeast, Calgary
# Strathcona Park, West, Calgary
# Sunalta, Centre, Calgary
# Sundance, South, Calgary
# Sunnyside, Centre, Calgary
# Sunridge, Northeast, Calgary
# Taradale, Northeast, Calgary
# Temple, Northeast, Calgary
# Thorncliffe, North, Calgary
# Tuscany, Northwest, Calgary
# Tuxedo Park, Centre, Calgary
# University Heights, Northwest, Calgary
# University of Calgary, Northwest, Calgary
# Upper Mount Royal, Centre, Calgary
# Valley Ridge, West, Calgary
# Valleyfield, East, Calgary
# Varsity, Northwest, Calgary
# Vista Heights, Northeast, Calgary
# Walden, South, Calgary
# West Hillhurst, Centre, Calgary
# West Springs, West, Calgary
# Westgate, West, Calgary
# Westwinds, Northeast, Calgary
# Whitehorn, Northeast, Calgary
# Wildwood, West, Calgary
# Willow Park, South, Calgary
# Windsor Park, Centre, Calgary
# Winston Heights/Mountview, Centre, Calgary
# Woodbine, South, Calgary
# Woodlands, South, Calgary
# Total City of Calgary, 1090936, Calgary
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 18     None
# 19     None
# 20     None
# 21     None
# 22     None
# 23     None
# 24     None
# 25     None
# 26     None
# 27     None
# 28     None
# 29     None
#        ...
# 228    None
# 229    None
# 230    None
# 231    None
# 232    None
# 233    None
# 234    None
# 235    None
# 236    None
# 237    None
# 238    None
# 239    None
# 240    None
# 241    None
# 242    None
# 243    None
# 244    None
# 245    None
# 246    None
# 247    None
# 248    None
# 249    None
# 250    None
# 251    None
# 252    None
# 253    None
# 254    None
# 255    None
# 256    None
# 257    None
# dtype: object

# %%
calgary_df['Latitude']=lat
calgary_df['Longitude']=lng

# %%
print(calgary_df['Latitude'].describe())
print(calgary_df['Longitude'].describe())
calgary_df.dropna(axis=0, inplace=True)
# Out:
# count    229.000000
# mean      51.040531
# std        0.070966
# min       50.856893
# 25%       50.997947
# 50%       51.047031
# 75%       51.088182
# max       51.178975
# Name: Latitude, dtype: float64
# count    229.000000
# mean    -114.069943
# std        0.077760
# min     -114.265072
# 25%     -114.115487
# 50%     -114.073960
# 75%     -114.010572
# max     -113.925905
# Name: Longitude, dtype: float64

# %%
calgary_df.shape
# Out:
# (229, 4)

# %%
calgary_df.reset_index(drop=True)
# Out:
#                       Neighborhood            Location   Latitude   Longitude
# 0                        Abbeydale  Northeast, Calgary  51.058836 -113.929413
# 1                           Acadia      South, Calgary  50.968655 -114.055587
# 2     Albert Park/Radisson Heights       East, Calgary  51.044845 -113.990195
# 3                         Altadore     Centre, Calgary  51.015104 -114.100756
# 4                 Alyth/Bonnybrook     Centre, Calgary  51.016669 -114.024294
# 5                   Applewood Park       East, Calgary  51.044658 -113.928931
# 6                      Arbour Lake  Northwest, Calgary  51.136786 -114.202355
# 7                      Aspen Woods       West, Calgary  51.043119 -114.210185
# 8                       Auburn Bay  Southeast, Calgary  50.890605 -113.959565
# 9             Aurora Business Park      North, Calgary  51.140549 -114.062707
# %%
# !pip install folium
import folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/72/ff/004bfe344150a064e558cb2aedeaa02ecbf75e60e148a55a9198f0c41765/folium-0.10.0-py2.py3-none-any.whl (91kB)
#      |████████████████████████████████| 92kB 3.5MB/s eta 0:00:011
# Requirement already satisfied: requests in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from folium) (2.14.2)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Collecting jinja2>=2.9 (from folium)
#   Using cached https://files.pythonhosted.org/packages/1d/e7/fd8b501e7a6dfe492a433deb7b9d833d39ca74916fa8bc63dd1a4947a671/Jinja2-2.10.1-py2.py3-none-any.whl
# Requirement already satisfied: numpy in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from folium) (1.17.0)
# Requirement already satisfied: six in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from branca>=0.3.0->folium) (1.11.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from jinja2>=2.9->folium) (0.23)
# Installing collected packages: jinja2, branca, folium
#   Found existing installation: Jinja2 2.8
#     Uninstalling Jinja2-2.8:
#       Successfully uninstalled Jinja2-2.8
# Successfully installed branca-0.3.1 folium-0.10.0 jinja2-2.10.1
# WARNING: You are using pip version 19.2.2, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
address = 'Calgary, Alberta'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 51.02532675 -114.049868485806

# %%
clat, clog = 51.0253,-114.0498
calgary_map = folium.Map([clat, clog], zoom_start=10)
calgary_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Visualize Calgary's neighborhood using folium

# %%
CLIENT_ID = 'XNINTZ000YTOTSL4NXGS4AUEFKRBR0BBRHO2NSGW3SR4GLOO' # your Foursquare ID
CLIENT_SECRET = '3HFK3SY5FNWWRLVYG25NYVH4V2W4D4QIXW5UCCQP4XEMHSWI' # your Foursquare Secret
VERSION = '20180605'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: XNINTZ000YTOTSL4NXGS4AUEFKRBR0BBRHO2NSGW3SR4GLOO
# CLIENT_SECRET:3HFK3SY5FNWWRLVYG25NYVH4V2W4D4QIXW5UCCQP4XEMHSWI

# %%
for label, lat, lng in zip(calgary_df['Neighborhood'], calgary_df['Latitude'], calgary_df['Longitude']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        location=[lat, lng],
        radius=10,
        popup=label,
        colur='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.6,
        parse_html=False
    ).add_to(calgary_map)
    
calgary_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def getNearbyRestaurants(names, latitudes, longitudes, radius=3000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&section=food&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()['response']['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
calgary_business = getNearbyRestaurants(names=calgary_df['Neighborhood'],
                                   latitudes=calgary_df['Latitude'],
                                   longitudes=calgary_df['Longitude']
                                  )
# Out:
# Abbeydale
# Acadia
# Albert Park/Radisson Heights
# Altadore
# Alyth/Bonnybrook
# Applewood Park
# Arbour Lake
# Aspen Woods
# Auburn Bay
# Aurora Business Park
# Banff Trail
# Bankview
# Bayview
# Beddington Heights
# Bel-Aire
# Beltline
# Bonavista Downs
# Bowness
# Braeside
# Brentwood
# Bridgeland/Riverside
# Bridlewood
# Britannia
# Burns Industrial
# Calgary International Airport
# Cambrian Heights
# Canada Olympic Park
# Canyon Meadows
# Capitol Hill
# Castleridge
# Cedarbrae
# Chaparral
# Charleswood
# Chinatown
# Chinook Park
# Christie Park
# Citadel
# Cliff Bungalow
# Coach Hill
# Collingwood
# Copperfield
# Coral Springs
# Cougar Ridge
# Country Hills
# Country Hills Village
# Coventry Hills
# Cranston
# Crescent Heights
# Crestmont
# Dalhousie
# Deer Ridge
# Deer Run
# Diamond Cove
# Discovery Ridge
# Dover
# Downtown Commercial Core
# Downtown East Village
# Downtown West End
# Eagle Ridge
# East Fairview Industrial
# East Shepard Industrial
# Eastfield
# Eau Claire
# Edgemont
# Elbow Park
# Elboya
# Erin Woods
# Erlton
# Evanston
# Evergreen
# Fairview
# Fairview Industrial
# Falconridge
# Foothills
# Forest Heights
# Forest Lawn
# Forest Lawn Industrial
# Franklin
# Glamorgan
# Glenbrook
# Glendale
# Golden Triangle
# Great Plains
# Greenview
# Greenview Industrial Park
# Greenwood/Greenbriar
# Hamptons
# Harvest Hills
# Hawkwood
# Haysboro
# Hidden Valley
# Highfield
# Highland Park
# Highwood
# Hillhurst
# Horizon
# Hounsfield Heights/Briar Hill
# Huntington Hills
# Inglewood
# Kelvin Grove
# Killarney/Glengarry
# Kincora
# Kingsland
# Lake Bonavista
# Lakeview
# Legacy
# Lincoln Park
# Lower Mount Royal
# MacEwan Glen
# Mahogany
# Manchester
# Manchester Industrial
# Maple Ridge
# Marlborough
# Marlborough Park
# Martindale
# Mayfair
# Mayland
# Mayland Heights
# McCall
# McKenzie Lake
# McKenzie Towne
# Meadowlark Park
# Meridian
# Midnapore
# Millrise
# Mission
# Monterey Park
# Montgomery
# Mount Pleasant
# New Brighton
# Nolan Hill
# North Airways
# North Glenmore Park
# North Haven
# North Haven Upper
# Nose Hill Park
# Oakridge
# Ogden
# Ogden Shops
# Palliser
# Panorama Hills
# Parkdale
# Parkhill
# Parkland
# Patterson
# Pegasus
# Penbrooke Meadows
# Pineridge
# Point Mckay
# Pump Hill
# Queens Park Village
# Queensland
# Ramsay
# Ranchlands
# Red Carpet
# Redstone
# Renfrew
# Richmond
# Rideau Park
# Riverbend
# Rocky Ridge
# Rosedale
# Rosemont
# Rosscarrock
# Roxboro
# Royal Oak
# Royal Vista
# Rundle
# Rutland Park
# Saddle Ridge
# Saddle Ridge Industrial
# Sage Hill
# Sandstone Valley
# Scarboro
# Scarboro/Sunalta West
# Scenic Acres
# Seton
# Shaganappi
# Shawnee Slopes
# Shawnessy
# Shepard Industrial
# Sherwood
# Signal Hill
# Silver Springs
# Silverado
# Skyline East
# Skyline West
# Skyview Ranch
# Somerset
# South Airways
# South Calgary
# South Foothills
# Southview
# Southwood
# Springbank Hill
# Spruce Cliff
# St. Andrews Heights
# Starfield
# Stonegate Landing
# Strathcona Park
# Sunalta
# Sundance
# Sunnyside
# Sunridge
# Taradale
# Temple
# Thorncliffe
# Tuscany
# Tuxedo Park
# University Heights
# University of Calgary
# Upper Mount Royal
# Valley Ridge
# Valleyfield
# Varsity
# Vista Heights
# Walden
# West Hillhurst
# West Springs
# Westgate
# Westwinds
# Whitehorn
# Wildwood
# Willow Park
# Windsor Park
# Winston Heights/Mountview
# Woodbine
# Woodlands

# %%
print(calgary_business.shape)
len(calgary_business['Venue Latitude'].unique())
# Out:
# (13226, 7)
# 1450

# %%
calgary_restaurants_unique = calgary_business.drop_duplicates(subset=['Venue Latitude', 'Venue Longitude'], keep='first')

# %%
calgary_restaurants_unique = calgary_restaurants_unique[calgary_restaurants_unique['Venue Category'].str.contains('Restaurant')]

# %%
#pd.set_option('display.max_rows', None)
calgary_restaurants_unique.head()
# Out:
#    Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 1     Abbeydale              51.058836             -113.929413
# 3     Abbeydale              51.058836             -113.929413
# 6     Abbeydale              51.058836             -113.929413
# 9     Abbeydale              51.058836             -113.929413
# 10    Abbeydale              51.058836             -113.929413
#
#                                Venue  Venue Latitude  Venue Longitude  \
# 1                         A&W Canada       51.068291      -113.933571
# 3   Song Huong Vietnamese Restaurant       51.038606      -113.942208
# 6                         McDonald's       51.075787      -113.958094
# 9                                KFC       51.064316      -113.957155
# 10                     Barrio Fiesta       51.052695      -113.935544
#
#            Venue Category
# 1    Fast Food Restaurant
# 3   Vietnamese Restaurant
# 6    Fast Food Restaurant
# 9    Fast Food Restaurant
# 10    Filipino Restaurant

# %% [markdown]
# ## Visualize all the venues in Calgary

# %%
clat, clng = 51.0253,-114.0498
calg_rest_map = folium.Map([clat, clng], zoom_start=10)
for label, lat, lng in zip(calgary_restaurants_unique['Venue'], calgary_restaurants_unique['Venue Latitude'], 
                           calgary_restaurants_unique['Venue Longitude']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        location=[lat, lng],
        radius=5,
        popup=label,
        colur='red',
        fill=True,
        fill_color='green',
        fill_opacity=0.6,
        parse_html=False
    ).add_to(calg_rest_map)
from IPython.display import display
display(calg_rest_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
calgary_restaurants_unique.groupby('Neighborhood').count()
# Out:
#                                Neighborhood Latitude  Neighborhood Longitude  \
# Neighborhood
# Abbeydale                                         15                      15
# Acadia                                            69                      69
# Albert Park/Radisson Heights                      55                      55
# Altadore                                          58                      58
# Alyth/Bonnybrook                                  19                      19
# Arbour Lake                                       32                      32
# Aspen Woods                                       18                      18
# Auburn Bay                                         9                       9
# Aurora Business Park                              31                      31
# Banff Trail                                       21                      21
# Bankview                                          33                      33
# Bayview                                           12                      12
# Beddington Heights                                 9                       9
# Bel-Aire                                           7                       7
# Beltline                                          11                      11
# Bonavista Downs                                   12                      12
# Bowness                                           29                      29
# Braeside                                           7                       7
# Brentwood                                         12                      12
# Bridgeland/Riverside                              22                      22
# Bridlewood                                         5                       5
# Britannia                                         12                      12
# Burns Industrial                                   1                       1
# Calgary International Airport                     22                      22
# Cambrian Heights                                  30                      30
# Canada Olympic Park                                1                       1
# Capitol Hill                                       7                       7
# Castleridge                                       25                      25
# Chaparral                                          4                       4
# Chinatown                                          2                       2
# ...                                              ...                     ...
# Inglewood                                         18                      18
# Killarney/Glengarry                                6                       6
# Lake Bonavista                                     1                       1
# Manchester                                         1                       1
# Manchester Industrial                              1                       1
# Maple Ridge                                        7                       7
# McCall                                             5                       5
# McKenzie Lake                                      6                       6
# Midnapore                                         24                      24
# Montgomery                                         2                       2
# Nose Hill Park                                     1                       1
# Parkdale                                           1                       1
# Pegasus                                            2                       2
# Point Mckay                                        1                       1
# Queens Park Village                                1                       1
# Richmond                                           9                       9
# Rocky Ridge                                        1                       1
# Rosemont                                           1                       1
# Saddle Ridge Industrial                            2                       2
# Scarboro/Sunalta West                              2                       2
# Shaganappi                                         4                       4
# Silverado                                          1                       1
# St. Andrews Heights                                2                       2
# Stonegate Landing                                  2                       2
# Strathcona Park                                    1                       1
# Valley Ridge                                       1                       1
# Vista Heights                                      2                       2
# West Hillhurst                                     4                       4
# Willow Park                                        1                       1
# Winston Heights/Mountview                          1                       1
#
#                                Venue  Venue Latitude  Venue Longitude  \
# Neighborhood
# Abbeydale                         15              15               15
# Acadia                            69              69               69
# Albert Park/Radisson Heights      55              55               55
# Altadore                          58              58               58
# Alyth/Bonnybrook                  19              19               19
# Arbour Lake                       32              32               32
# Aspen Woods                       18              18               18
# Auburn Bay                         9               9                9
# Aurora Business Park              31              31               31
# Banff Trail                       21              21               21
# Bankview                          33              33               33
# Bayview                           12              12               12
# Beddington Heights                 9               9                9
# Bel-Aire                           7               7                7
# Beltline                          11              11               11
# Bonavista Downs                   12              12               12
# Bowness                           29              29               29
# Braeside                           7               7                7
# Brentwood                         12              12               12
# Bridgeland/Riverside              22              22               22
# Bridlewood                         5               5                5
# Britannia                         12              12               12
# Burns Industrial                   1               1                1
# Calgary International Airport     22              22               22
# Cambrian Heights                  30              30               30
# Canada Olympic Park                1               1                1
# Capitol Hill                       7               7                7
# Castleridge                       25              25               25
# Chaparral                          4               4                4
# Chinatown                          2               2                2
# ...                              ...             ...              ...
# Inglewood                         18              18               18
# Killarney/Glengarry                6               6                6
# Lake Bonavista                     1               1                1
# Manchester                         1               1                1
# Manchester Industrial              1               1                1
# Maple Ridge                        7               7                7
# McCall                             5               5                5
# McKenzie Lake                      6               6                6
# Midnapore                         24              24               24
# Montgomery                         2               2                2
# Nose Hill Park                     1               1                1
# Parkdale                           1               1                1
# Pegasus                            2               2                2
# Point Mckay                        1               1                1
# Queens Park Village                1               1                1
# Richmond                           9               9                9
# Rocky Ridge                        1               1                1
# Rosemont                           1               1                1
# Saddle Ridge Industrial            2               2                2
# Scarboro/Sunalta West              2               2                2
# Shaganappi                         4               4                4
# Silverado                          1               1                1
# St. Andrews Heights                2               2                2
# Stonegate Landing                  2               2                2
# Strathcona Park                    1               1                1
# Valley Ridge                       1               1                1
# Vista Heights                      2               2                2
# West Hillhurst                     4               4                4
# Willow Park                        1               1                1
# Winston Heights/Mountview          1               1                1
#
#                                Venue Category
# Neighborhood
# Abbeydale                                  15
# Acadia                                     69
# Albert Park/Radisson Heights               55
# Altadore                                   58
# Alyth/Bonnybrook                           19
# Arbour Lake                                32
# Aspen Woods                                18
# Auburn Bay                                  9
# Aurora Business Park                       31
# Banff Trail                                21
# Bankview                                   33
# Bayview                                    12
# Beddington Heights                          9
# Bel-Aire                                    7
# Beltline                                   11
# Bonavista Downs                            12
# Bowness                                    29
# Braeside                                    7
# Brentwood                                  12
# Bridgeland/Riverside                       22
# Bridlewood                                  5
# Britannia                                  12
# Burns Industrial                            1
# Calgary International Airport              22
# Cambrian Heights                           30
# Canada Olympic Park                         1
# Capitol Hill                                7
# Castleridge                                25
# Chaparral                                   4
# Chinatown                                   2
# ...                                       ...
# Inglewood                                  18
# Killarney/Glengarry                         6
# Lake Bonavista                              1
# Manchester                                  1
# Manchester Industrial                       1
# Maple Ridge                                 7
# McCall                                      5
# McKenzie Lake                               6
# Midnapore                                  24
# Montgomery                                  2
# Nose Hill Park                              1
# Parkdale                                    1
# Pegasus                                     2
# Point Mckay                                 1
# Queens Park Village                         1
# Richmond                                    9
# Rocky Ridge                                 1
# Rosemont                                    1
# Saddle Ridge Industrial                     2
# Scarboro/Sunalta West                       2
# Shaganappi                                  4
# Silverado                                   1
# St. Andrews Heights                         2
# Stonegate Landing                           2
# Strathcona Park                             1
# Valley Ridge                                1
# Vista Heights                               2
# West Hillhurst                              4
# Willow Park                                 1
# Winston Heights/Mountview                   1
#
# [97 rows x 6 columns]

# %%
calgary_onehot = pd.get_dummies(calgary_restaurants_unique['Venue Category'])
calgary_onehot.insert(loc=0, column='Neighborhood', value=calgary_restaurants_unique['Neighborhood'])

# %%
calgary_onehot.head()
# Out:
#    Neighborhood  African Restaurant  American Restaurant  \
# 1     Abbeydale                   0                    0
# 3     Abbeydale                   0                    0
# 6     Abbeydale                   0                    0
# 9     Abbeydale                   0                    0
# 10    Abbeydale                   0                    0
#
#     Argentinian Restaurant  Asian Restaurant  Belgian Restaurant  \
# 1                        0                 0                   0
# 3                        0                 0                   0
# 6                        0                 0                   0
# 9                        0                 0                   0
# 10                       0                 0                   0
#
#     Brazilian Restaurant  Cajun / Creole Restaurant  Chinese Restaurant  \
# 1                      0                          0                   0
# 3                      0                          0                   0
# 6                      0                          0                   0
# 9                      0                          0                   0
# 10                     0                          0                   0
#
#     Dim Sum Restaurant          ...            Shabu-Shabu Restaurant  \
# 1                    0          ...                                 0
# 3                    0          ...                                 0
# 6                    0          ...                                 0
# 9                    0          ...                                 0
# 10                   0          ...                                 0
#
#     Southern / Soul Food Restaurant  Sushi Restaurant  Swiss Restaurant  \
# 1                                 0                 0                 0
# 3                                 0                 0                 0
# 6                                 0                 0                 0
# 9                                 0                 0                 0
# 10                                0                 0                 0
#
#     Tapas Restaurant  Tex-Mex Restaurant  Thai Restaurant  Turkish Restaurant  \
# 1                  0                   0                0                   0
# 3                  0                   0                0                   0
# 6                  0                   0                0                   0
# 9                  0                   0                0                   0
# 10                 0                   0                0                   0
#
#     Vegetarian / Vegan Restaurant  Vietnamese Restaurant
# 1                               0                      0
# 3                               0                      1
# 6                               0                      0
# 9                               0                      0
# 10                              0                      0
#
# [5 rows x 52 columns]

# %%
calgary_grouped = calgary_onehot.groupby('Neighborhood').mean().reset_index()

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = calgary_grouped['Neighborhood']

for ind in np.arange(calgary_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(calgary_grouped.iloc[ind, :], num_top_venues)

# %% [markdown]
# ## Top 10 Venues in each neighborhood

# %%
neighborhoods_venues_sorted.head(10)
# Out:
#                    Neighborhood  1st Most Common Venue  2nd Most Common Venue  \
# 0                     Abbeydale   Fast Food Restaurant  Vietnamese Restaurant
# 1                        Acadia   Fast Food Restaurant  Vietnamese Restaurant
# 2  Albert Park/Radisson Heights  Vietnamese Restaurant   Fast Food Restaurant
# 3                      Altadore  Vietnamese Restaurant             Restaurant
# 4              Alyth/Bonnybrook   Fast Food Restaurant             Restaurant
# 5                   Arbour Lake   Fast Food Restaurant  Vietnamese Restaurant
# 6                   Aspen Woods             Restaurant  Vietnamese Restaurant
# 7                    Auburn Bay       Sushi Restaurant  Portuguese Restaurant
# 8          Aurora Business Park   Fast Food Restaurant  Vietnamese Restaurant
# 9                   Banff Trail   Fast Food Restaurant    American Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue  \
# 0     Italian Restaurant      Asian Restaurant     Chinese Restaurant
# 1       Sushi Restaurant   American Restaurant             Restaurant
# 2      Indian Restaurant    Chinese Restaurant             Restaurant
# 3     Mexican Restaurant  Fast Food Restaurant      French Restaurant
# 4  Vietnamese Restaurant   American Restaurant     Chinese Restaurant
# 5     Chinese Restaurant   Japanese Restaurant       Greek Restaurant
# 6    American Restaurant      Asian Restaurant       Sushi Restaurant
# 7     Italian Restaurant            Restaurant     Seafood Restaurant
# 8     Chinese Restaurant    Italian Restaurant    American Restaurant
# 9     Chinese Restaurant   Japanese Restaurant  Vietnamese Restaurant
#
#          6th Most Common Venue     7th Most Common Venue  \
# 0                   Restaurant       Filipino Restaurant
# 1           Italian Restaurant        Mexican Restaurant
# 2           Mexican Restaurant          Asian Restaurant
# 3          American Restaurant          Greek Restaurant
# 4  Eastern European Restaurant  Mediterranean Restaurant
# 5           Mexican Restaurant          Sushi Restaurant
# 6          Japanese Restaurant         Indian Restaurant
# 7          Japanese Restaurant          Asian Restaurant
# 8                   Restaurant       Japanese Restaurant
# 9                   Restaurant          Asian Restaurant
#
#    8th Most Common Venue      9th Most Common Venue     10th Most Common Venue
# 0  Indonesian Restaurant          Indian Restaurant          Hotpot Restaurant
# 1       Asian Restaurant         Chinese Restaurant           Greek Restaurant
# 2    American Restaurant         Italian Restaurant         Falafel Restaurant
# 3      Indian Restaurant         Italian Restaurant        Japanese Restaurant
# 4      French Restaurant        Japanese Restaurant        Empanada Restaurant
# 5             Restaurant   Mediterranean Restaurant  Middle Eastern Restaurant
# 6     Mexican Restaurant  Middle Eastern Restaurant       Fast Food Restaurant
# 7    American Restaurant       Brazilian Restaurant       Fast Food Restaurant
# 8      Indian Restaurant       Hong Kong Restaurant   Mediterranean Restaurant
# 9       Greek Restaurant          Indian Restaurant   Mediterranean Restaurant

# %% [markdown]
# ## Clustering Neighborhoods

# %% [markdown]
# Cluster Neighborhoods and Examine Clusters First, let's determine the optimal value of K for our dataset using the Silhouette Coefficient Method

# %%
calgary_grouped_clustering = calgary_grouped.drop('Neighborhood', 1)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
for n_cluster in range(2, 10):
    kmeans = KMeans(n_clusters=n_cluster).fit(calgary_grouped_clustering)
    label = kmeans.labels_
    sil_coeff = silhouette_score(calgary_grouped_clustering, label, metric='euclidean')
    print("For n_clusters={}, The Silhouette Coefficient is {}".format(n_cluster, sil_coeff))
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.28126870786830566
# For n_clusters=3, The Silhouette Coefficient is 0.1744630114864016
# For n_clusters=4, The Silhouette Coefficient is 0.14732137194529585
# For n_clusters=5, The Silhouette Coefficient is 0.3056347682850061
# For n_clusters=6, The Silhouette Coefficient is 0.28318376054472827
# For n_clusters=7, The Silhouette Coefficient is 0.2247706754636227
# For n_clusters=8, The Silhouette Coefficient is 0.25121474538225613
# For n_clusters=9, The Silhouette Coefficient is 0.27037438453928586

# %% [markdown]
# As we can see, n_clusters=6 has highest Silhouette Coefficient. This means that 6 should be the optimal number of clusters. For n_clusters=6, The Silhouette Coefficient is 0.3254202332087556
#
# Run k-means to cluster the neighborhood into 6 clusters.

# %%
# %matplotlib inline
# set number of clusters
kclusters = 5

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(calgary_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:6]
# Out:
# array([0, 1, 1, 1, 1, 1], dtype=int32)

# %%
#del calgary_merged['Cluster Labels']
#calgary_merged
#del neighborhoods_venues_sorted['Cluster Labels']

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

calgary_merged = calgary_df

# merge calgary_grouped with calgary_data to add latitude/longitude for each neighborhood
calgary_merged = calgary_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
calgary_merged.head()
# Out:
#                    Neighborhood            Location   Latitude   Longitude  \
# 0                     Abbeydale  Northeast, Calgary  51.058836 -113.929413
# 1                        Acadia      South, Calgary  50.968655 -114.055587
# 2  Albert Park/Radisson Heights       East, Calgary  51.044845 -113.990195
# 3                      Altadore     Centre, Calgary  51.015104 -114.100756
# 4              Alyth/Bonnybrook     Centre, Calgary  51.016669 -114.024294
#
#    Cluster Labels  1st Most Common Venue  2nd Most Common Venue  \
# 0             0.0   Fast Food Restaurant  Vietnamese Restaurant
# 1             1.0   Fast Food Restaurant  Vietnamese Restaurant
# 2             1.0  Vietnamese Restaurant   Fast Food Restaurant
# 3             1.0  Vietnamese Restaurant             Restaurant
# 4             1.0   Fast Food Restaurant             Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0     Italian Restaurant      Asian Restaurant    Chinese Restaurant
# 1       Sushi Restaurant   American Restaurant            Restaurant
# 2      Indian Restaurant    Chinese Restaurant            Restaurant
# 3     Mexican Restaurant  Fast Food Restaurant     French Restaurant
# 4  Vietnamese Restaurant   American Restaurant    Chinese Restaurant
#
#          6th Most Common Venue     7th Most Common Venue  \
# 0                   Restaurant       Filipino Restaurant
# 1           Italian Restaurant        Mexican Restaurant
# 2           Mexican Restaurant          Asian Restaurant
# 3          American Restaurant          Greek Restaurant
# 4  Eastern European Restaurant  Mediterranean Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0  Indonesian Restaurant     Indian Restaurant      Hotpot Restaurant
# 1       Asian Restaurant    Chinese Restaurant       Greek Restaurant
# 2    American Restaurant    Italian Restaurant     Falafel Restaurant
# 3      Indian Restaurant    Italian Restaurant    Japanese Restaurant
# 4      French Restaurant   Japanese Restaurant    Empanada Restaurant

# %%
calgary_merged['Cluster Labels'] = calgary_merged['Cluster Labels'].fillna(0)
calgary_merged['Cluster Labels'] = calgary_merged['Cluster Labels'].astype(int)
calgary_merged.dropna(inplace=True)

# %%
# create map
map_clusters = folium.Map(location=[clat, clng], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(calgary_merged['Latitude'], calgary_merged['Longitude'], calgary_merged['Neighborhood'], calgary_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=10,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Examining the Clusters

# %%
calgary_merged.loc[calgary_merged['Cluster Labels'] == 0, calgary_merged.columns[[0] + list(range(5, calgary_merged.shape[1]))]]
# Out:
#              Neighborhood  1st Most Common Venue     2nd Most Common Venue  \
# 0               Abbeydale   Fast Food Restaurant     Vietnamese Restaurant
# 36           Chinook Park   Fast Food Restaurant        Italian Restaurant
# 44          Coral Springs   Fast Food Restaurant     Vietnamese Restaurant
# 66              Eastfield   Fast Food Restaurant  Mediterranean Restaurant
# 73               Evanston   Fast Food Restaurant     Vietnamese Restaurant
# 80         Forest Heights    American Restaurant      Fast Food Restaurant
# 93   Greenwood/Greenbriar   Fast Food Restaurant     Vietnamese Restaurant
# 103               Horizon  Vietnamese Restaurant      Fast Food Restaurant
# 160   Queens Park Village   Fast Food Restaurant     Vietnamese Restaurant
# 184           Rocky Ridge   Fast Food Restaurant     Vietnamese Restaurant
# 252           Willow Park   Fast Food Restaurant     Vietnamese Restaurant
#
#      3rd Most Common Venue  4th Most Common Venue  5th Most Common Venue  \
# 0       Italian Restaurant       Asian Restaurant     Chinese Restaurant
# 36        Asian Restaurant  Vietnamese Restaurant     Falafel Restaurant
# 44      Falafel Restaurant     Italian Restaurant  Indonesian Restaurant
# 66        Sushi Restaurant     Chinese Restaurant  Vietnamese Restaurant
# 73       Indian Restaurant       Asian Restaurant       Sushi Restaurant
# 80   Vietnamese Restaurant     Falafel Restaurant     Italian Restaurant
# 93      Falafel Restaurant     Italian Restaurant  Indonesian Restaurant
# 103    American Restaurant     Falafel Restaurant     Italian Restaurant
# 160     Falafel Restaurant     Italian Restaurant  Indonesian Restaurant
# 184     Falafel Restaurant     Italian Restaurant  Indonesian Restaurant
# 252     Falafel Restaurant     Italian Restaurant  Indonesian Restaurant
#
#      6th Most Common Venue  7th Most Common Venue  8th Most Common Venue  \
# 0               Restaurant    Filipino Restaurant  Indonesian Restaurant
# 36   Indonesian Restaurant      Indian Restaurant      Hotpot Restaurant
# 44       Indian Restaurant      Hotpot Restaurant   Hong Kong Restaurant
# 66      Falafel Restaurant  Indonesian Restaurant      Indian Restaurant
# 73        Greek Restaurant             Restaurant    Japanese Restaurant
# 80   Indonesian Restaurant      Indian Restaurant      Hotpot Restaurant
# 93       Indian Restaurant      Hotpot Restaurant   Hong Kong Restaurant
# 103  Indonesian Restaurant      Indian Restaurant      Hotpot Restaurant
# 160      Indian Restaurant      Hotpot Restaurant   Hong Kong Restaurant
# 184      Indian Restaurant      Hotpot Restaurant   Hong Kong Restaurant
# 252      Indian Restaurant      Hotpot Restaurant   Hong Kong Restaurant
#
#     9th Most Common Venue  10th Most Common Venue
# 0       Indian Restaurant       Hotpot Restaurant
# 36   Hong Kong Restaurant        Greek Restaurant
# 44       Greek Restaurant  Gluten-free Restaurant
# 66      Hotpot Restaurant    Hong Kong Restaurant
# 73     Falafel Restaurant   Indonesian Restaurant
# 80   Hong Kong Restaurant        Greek Restaurant
# 93       Greek Restaurant  Gluten-free Restaurant
# 103  Hong Kong Restaurant        Greek Restaurant
# 160      Greek Restaurant  Gluten-free Restaurant
# 184      Greek Restaurant  Gluten-free Restaurant
# 252      Greek Restaurant  Gluten-free Restaurant

# %%
calgary_merged.loc[calgary_merged['Cluster Labels'] == 1, calgary_merged.columns[[0] + list(range(5, calgary_merged.shape[1]))]]
# Out:
#                       Neighborhood      1st Most Common Venue  \
# 1                           Acadia       Fast Food Restaurant
# 2     Albert Park/Radisson Heights      Vietnamese Restaurant
# 3                         Altadore      Vietnamese Restaurant
# 4                 Alyth/Bonnybrook       Fast Food Restaurant
# 6                      Arbour Lake       Fast Food Restaurant
# 7                      Aspen Woods                 Restaurant
# 8                       Auburn Bay           Sushi Restaurant
# 9             Aurora Business Park       Fast Food Restaurant
# 10                     Banff Trail       Fast Food Restaurant
# 11                        Bankview                 Restaurant
# 12                         Bayview       Fast Food Restaurant
# 13              Beddington Heights         Chinese Restaurant
# 14                        Bel-Aire        Japanese Restaurant
# 15                        Beltline         Italian Restaurant
# 16                 Bonavista Downs      Vietnamese Restaurant
# 17                         Bowness       Fast Food Restaurant
# 18                        Braeside                 Restaurant
# 19                       Brentwood       Fast Food Restaurant
# 20            Bridgeland/Riverside         Italian Restaurant
# 21                      Bridlewood         Falafel Restaurant
# 22                       Britannia           Sushi Restaurant
# 23                Burns Industrial  Middle Eastern Restaurant
# 24   Calgary International Airport        American Restaurant
# 25                Cambrian Heights         Chinese Restaurant
# 26             Canada Olympic Park           Greek Restaurant
# 28                    Capitol Hill         Chinese Restaurant
# 29                     Castleridge          Indian Restaurant
# 33                       Chaparral           Sushi Restaurant
# 35                       Chinatown           Sushi Restaurant
# 37                   Christie Park       Fast Food Restaurant
# ..                             ...                        ...
# 74                       Evergreen           Sushi Restaurant
# 79                       Foothills          Indian Restaurant
# 83                        Franklin       Fast Food Restaurant
# 84                       Glamorgan      Vietnamese Restaurant
# 85                       Glenbrook   Mediterranean Restaurant
# 91                       Greenview       Fast Food Restaurant
# 92       Greenview Industrial Park         Mexican Restaurant
# 94                        Hamptons      Vietnamese Restaurant
# 99                       Highfield         Falafel Restaurant
# 100                  Highland Park      Vietnamese Restaurant
# 107                      Inglewood                 Restaurant
# 109            Killarney/Glengarry         Mexican Restaurant
# 120          Manchester Industrial                 Restaurant
# 121                    Maple Ridge           Asian Restaurant
# 128                         McCall         Chinese Restaurant
# 129                  McKenzie Lake        Japanese Restaurant
# 133                      Midnapore       Fast Food Restaurant
# 137                     Montgomery         Mexican Restaurant
# 151                       Parkdale                 Restaurant
# 181                       Richmond         Italian Restaurant
# 186                       Rosemont          Korean Restaurant
# 194        Saddle Ridge Industrial        American Restaurant
# 198          Scarboro/Sunalta West           Tapas Restaurant
# 202                     Shaganappi           Sushi Restaurant
# 209                      Silverado           Asian Restaurant
# 221            St. Andrews Heights         Falafel Restaurant
# 223              Stonegate Landing        American Restaurant
# 241                   Valley Ridge                 Restaurant
# 244                  Vista Heights      Vietnamese Restaurant
# 246                 West Hillhurst         Falafel Restaurant
#
#            2nd Most Common Venue      3rd Most Common Venue  \
# 1          Vietnamese Restaurant           Sushi Restaurant
# 2           Fast Food Restaurant          Indian Restaurant
# 3                     Restaurant         Mexican Restaurant
# 4                     Restaurant      Vietnamese Restaurant
# 6          Vietnamese Restaurant         Chinese Restaurant
# 7          Vietnamese Restaurant        American Restaurant
# 8          Portuguese Restaurant         Italian Restaurant
# 9          Vietnamese Restaurant         Chinese Restaurant
# 10           American Restaurant         Chinese Restaurant
# 11         Vietnamese Restaurant          Korean Restaurant
# 12              Sushi Restaurant      Vietnamese Restaurant
# 13          Fast Food Restaurant      Vietnamese Restaurant
# 14              Greek Restaurant           Sushi Restaurant
# 15           American Restaurant           Sushi Restaurant
# 16          Fast Food Restaurant           Asian Restaurant
# 17           American Restaurant          Korean Restaurant
# 18           American Restaurant           Asian Restaurant
# 19         Vietnamese Restaurant                 Restaurant
# 20            Chinese Restaurant  Middle Eastern Restaurant
# 21              Sushi Restaurant         Mexican Restaurant
# 22         Vietnamese Restaurant       Fast Food Restaurant
# 23         Vietnamese Restaurant           Kebab Restaurant
# 24          Fast Food Restaurant                 Restaurant
# 25         Vietnamese Restaurant        American Restaurant
# 26         Vietnamese Restaurant         Falafel Restaurant
# 28            Falafel Restaurant            Thai Restaurant
# 29          Fast Food Restaurant      Vietnamese Restaurant
# 33            Mexican Restaurant                 Restaurant
# 35   Eastern European Restaurant      Vietnamese Restaurant
# 37         Vietnamese Restaurant        Japanese Restaurant
# ..                           ...                        ...
# 74         Vietnamese Restaurant         Falafel Restaurant
# 79                    Restaurant      Vietnamese Restaurant
# 83         Vietnamese Restaurant        American Restaurant
# 84              Sushi Restaurant        Japanese Restaurant
# 85            Seafood Restaurant      Vietnamese Restaurant
# 91              Ramen Restaurant           Malay Restaurant
# 92              Sushi Restaurant      Vietnamese Restaurant
# 94           American Restaurant       Fast Food Restaurant
# 99         Vietnamese Restaurant         Italian Restaurant
# 100           Falafel Restaurant         Italian Restaurant
# 107           Chinese Restaurant      Vietnamese Restaurant
# 109            Korean Restaurant           Sushi Restaurant
# 120        Vietnamese Restaurant         Falafel Restaurant
# 121         Fast Food Restaurant      Vietnamese Restaurant
# 128          American Restaurant  Middle Eastern Restaurant
# 129         Fast Food Restaurant        American Restaurant
# 133        Vietnamese Restaurant         Chinese Restaurant
# 137             Sushi Restaurant      Vietnamese Restaurant
# 151        Vietnamese Restaurant         Falafel Restaurant
# 181          American Restaurant          Indian Restaurant
# 186           Falafel Restaurant         Italian Restaurant
# 194           Tex-Mex Restaurant      Vietnamese Restaurant
# 198             Sushi Restaurant      Vietnamese Restaurant
# 202           Mexican Restaurant          French Restaurant
# 209        Vietnamese Restaurant         Falafel Restaurant
# 221             Sushi Restaurant      Vietnamese Restaurant
# 223           Mexican Restaurant      Vietnamese Restaurant
# 241        Vietnamese Restaurant         Falafel Restaurant
# 244            Korean Restaurant         Turkish Restaurant
# 246           Chinese Restaurant   Mediterranean Restaurant
#
#                4th Most Common Venue     5th Most Common Venue  \
# 1                American Restaurant                Restaurant
# 2                 Chinese Restaurant                Restaurant
# 3               Fast Food Restaurant         French Restaurant
# 4                American Restaurant        Chinese Restaurant
# 6                Japanese Restaurant          Greek Restaurant
# 7                   Asian Restaurant          Sushi Restaurant
# 8                         Restaurant        Seafood Restaurant
# 9                 Italian Restaurant       American Restaurant
# 10               Japanese Restaurant     Vietnamese Restaurant
# 11               Moroccan Restaurant         French Restaurant
# 12                Dim Sum Restaurant        Falafel Restaurant
# 13                 Indian Restaurant          Sushi Restaurant
# 14   Southern / Soul Food Restaurant        Mexican Restaurant
# 15          Mediterranean Restaurant   New American Restaurant
# 16                Chinese Restaurant                Restaurant
# 17                  Sushi Restaurant        Chinese Restaurant
# 18                  Sushi Restaurant        Chinese Restaurant
# 19               American Restaurant          Asian Restaurant
# 20                        Restaurant     Vietnamese Restaurant
# 21                Chinese Restaurant        Seafood Restaurant
# 22         Latin American Restaurant          Greek Restaurant
# 23                Italian Restaurant     Indonesian Restaurant
# 24                Chinese Restaurant       Japanese Restaurant
# 25              Fast Food Restaurant          Sushi Restaurant
# 26                Italian Restaurant     Indonesian Restaurant
# 28                 Indian Restaurant          Sushi Restaurant
# 29                  Asian Restaurant        Chinese Restaurant
# 33              Fast Food Restaurant     Vietnamese Restaurant
# 35                Falafel Restaurant        Italian Restaurant
# 37               American Restaurant          Greek Restaurant
# ..                               ...                       ...
# 74                Italian Restaurant     Indonesian Restaurant
# 79                Falafel Restaurant        Italian Restaurant
# 83                   Thai Restaurant     Portuguese Restaurant
# 84            Argentinian Restaurant      Fast Food Restaurant
# 85                Falafel Restaurant     Indonesian Restaurant
# 91                Chinese Restaurant                Restaurant
# 92                Falafel Restaurant     Indonesian Restaurant
# 94                Falafel Restaurant        Italian Restaurant
# 99             Indonesian Restaurant         Indian Restaurant
# 100            Indonesian Restaurant         Indian Restaurant
# 107                 Asian Restaurant       Japanese Restaurant
# 109                       Restaurant      Fast Food Restaurant
# 120               Italian Restaurant     Indonesian Restaurant
# 121               Mexican Restaurant        Falafel Restaurant
# 128                       Restaurant     Vietnamese Restaurant
# 129               Italian Restaurant        Mexican Restaurant
# 133              American Restaurant                Restaurant
# 137               Falafel Restaurant     Indonesian Restaurant
# 151               Italian Restaurant     Indonesian Restaurant
# 181                 Sushi Restaurant  Mediterranean Restaurant
# 186            Indonesian Restaurant         Indian Restaurant
# 194               Falafel Restaurant        Italian Restaurant
# 198             Ethiopian Restaurant     Indonesian Restaurant
# 202            Vietnamese Restaurant        Falafel Restaurant
# 209               Italian Restaurant     Indonesian Restaurant
# 221               Italian Restaurant     Indonesian Restaurant
# 223             Fast Food Restaurant        Italian Restaurant
# 241               Italian Restaurant     Indonesian Restaurant
# 244              Japanese Restaurant     Indonesian Restaurant
# 246    Vegetarian / Vegan Restaurant          Asian Restaurant
#
#            6th Most Common Venue        7th Most Common Venue  \
# 